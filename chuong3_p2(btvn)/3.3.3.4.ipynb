# %%
import numpy as np
arr = np.arange(1,10)  #Tạo mảng 1 chiều có 9 phần tử từ 1 đến 9
grid = arr.reshape((3,3))  # Chuyển đổi mảng arr thành mảng grid 3x3
arr
grid
# Out:
# array([[1, 2, 3],
#        [4, 5, 6],
#        [7, 8, 9]])
